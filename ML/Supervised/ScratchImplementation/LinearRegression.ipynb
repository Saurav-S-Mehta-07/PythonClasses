# %% [markdown]
# # \# Scratch Implementation of LinearRegression

# %%
import numpy as np

# %%
class LinearRegression:
    def __init__(self, learning_rate=0.01, n_iter=1000):
        self.bias = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def fit(self,X,y):# X_train, y_train 
        
        m,n =  X.shape # number of samples and no of features (rows,cols)

        # step 1
        self.bias = 0
        self.weights = np.zeros(n) # array of zeros

        # Gradient Descent
        for i in range(self.n_iter) :
            
            # step 2
            y_pred = self.bias + np.dot(X, self.weights)

            # step 3
            db = (1/m) * np.sum(y_pred-y) # derivative with respect to bias
            dw = (1/m) * np.dot(X.T, (y_pred-y))# derivative with respect to coeficient

            # step 4
            self.bias -= self.lr * db
            self.weights -= self.lr * dw
               
        
    def predict(self,X):
        y_pred = self.bias + np.dot(X, self.weights)
        return y_pred

# %%
# input data
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])
# best prediction y = 2x

# %%
model = LinearRegression()
model.fit(X,y)

y_pred = model.predict(X)
print(y_pred)
print("model bias : ", model.bias)
print("model coefficient : ", model.weights)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]
# model bias :  0.09475321533750963
# model coefficient :  [1.97375488]

# %% [markdown]
# # \# Implementaion via OLS

# %%
import numpy as np

class LinearRegression:

    def __init__(self):
        self.bias = None
        self.weights = None

    def fit(self, X, y):
        m, n = X.shape

        # Add bias column
        X_b = np.c_[np.ones((m, 1)), X]

        # Normal Equation (OLS)
        theta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

        self.bias = theta[0]
        self.weights = theta[1:]

    def predict(self, X):
        return self.bias + np.dot(X, self.weights)

# %%
# input data
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])
# best prediction y = 2x

model = LinearRegression()
model.fit(X,y)

y_pred = model.predict(X)
print(y_pred)
print("model bias : ", model.bias)
print("model coefficient : ", model.weights)
# Out:
# [ 2.  4.  6.  8. 10.]
# model bias :  5.329070518200751e-15
# model coefficient :  [2.]
